# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\David\\Desktop\\Databases\\Veit1.csv')

# %%
df['t_stamp2'] = pd.to_datetime(df['t_stamp'],format='%d/%m/%y %H:%M')

# %%
plt.plot(df['t_stamp2'],df['zona de calor1'])
plt.plot(df['t_stamp2'],df['resistencia1'])
plt.show()

# %%
df.corr()
# Out:
#                       resistencia1  resistencia2  resistencia3  resistencia4  \
# resistencia1              1.000000      0.981304      0.975347      0.977268
# resistencia2              0.981304      1.000000      0.994199      0.994939
# resistencia3              0.975347      0.994199      1.000000      0.984843
# resistencia4              0.977268      0.994939      0.984843      1.000000
# resistencia5              0.813065      0.788193      0.782398      0.782927
# rodillo flexo             0.758805      0.768313      0.758407      0.769401
# temperatura ambiente      0.184354      0.184511      0.166535      0.181473
# temperatura de banda      0.544032      0.553584      0.526635      0.593923
# tiempociclo               0.049948      0.061654      0.065612      0.063094
# velocidad                -0.133118     -0.047220     -0.079778     -0.033695
# zona de calor1            0.957555      0.945257      0.920078      0.945803
# ...

# %%
corr = df.corr()
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values)
